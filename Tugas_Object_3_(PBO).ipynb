# %% [markdown]
# <a href="https://colab.research.google.com/github/ismichairunisa/TugasObject3/blob/main/Tugas_Object_3_(PBO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variabel Kelas
class Person:
    person = 'Person'

    # Metode konstruktor / init
    def __init__(self, rambut, warna):
        # Variabel instansi
        self.rambut = rambut
        self.warna = warna

# Objek
Budi = Person("Ikal", "Hitam")
Michael = Person("Lurus", "Pirang")

print('Detail Budi:')
print('Rambut: ', Budi.rambut)
print('Warna Rambut: ', Budi.warna)

print('\nDetail Michael:')
print('Rambut: ', Michael.rambut)
print('Warna Rambut: ', Michael.warna)
# Out:
# Detail Budi:
# Rambut:  Ikal
# Warna Rambut:  Hitam
#
# Detail Michael:
# Rambut:  Lurus
# Warna Rambut:  Pirang
